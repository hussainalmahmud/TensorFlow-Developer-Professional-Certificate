# %%
import tensorflow as tf
from os import path, getcwd, chdir

# %%
path = f"{getcwd()}/../mnist.npz"

# %%
path
# Out:
# '/content/../mnist.npz'

# %%
#config = tf.ConfigProto()
#config.gpu_options.allow_growth = True
#sess = tf.Session(config=config)

# %%
# GRADED FUNCTION: train_mnist_conv
def train_mnist_conv():
    # Please write your code only where you are indicated.
    # please do not remove model fitting inline comments.

    # YOUR CODE STARTS HERE
    class myCallback(tf.keras.callbacks.Callback):
      def on_epoch_end(self, epoch, logs={}):
        if logs.get('acc') is not None and logs.get('acc') > 0.998:
          print("\nReached 99.8% accuracy so canceling the training!")
          self.model.stop_training = True
    callbacks = myCallback()
    # YOUR CODE ENDS HERE

    mnist = tf.keras.datasets.mnist
    (training_images, training_labels), (test_images, test_labels) = mnist.load_data(path=path)
    # YOUR CODE STARTS HERE
    training_images = training_images.reshape(60000, 28,28,1)
    test_images = test_images.reshape(10000, 28,28,1)
    training_images = training_images / 255.0
    test_images = test_images / 255.0
    # YOUR CODE ENDS HERE

    model = tf.keras.models.Sequential([
            # YOUR CODE STARTS HERE
            # Try to simplify the architecture as much as possible. You can reach the target accuracy
            # with just a single convolution and max pooling followed by the usual flatten and dense layers.
            # If you get grader timeouts in your submission, try to minimize the number of convolution filters 
            # and dense units.
            tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
            tf.keras.layers.MaxPooling2D(2, 2),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(10, activation='softmax'),
            # YOUR CODE ENDS HERE
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    # model fitting
    history = model.fit(
        # YOUR CODE STARTS HERE
        # Remember to set a callback function to stop the training when the target accuracy is reached. 
        # It should be met in less than 20 epochs.
        training_images,training_labels, epochs=10, callbacks=[callbacks]
        # YOUR CODE ENDS HERE
    )
    # model fitting
    return history.epoch, history.history['accuracy'][-1]

# %%
_, _ = train_mnist_conv()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 42s 22ms/step - loss: 0.1604 - accuracy: 0.9516
# Epoch 2/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0538 - accuracy: 0.9837
# Epoch 3/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0349 - accuracy: 0.9889
# Epoch 4/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0224 - accuracy: 0.9928
# Epoch 5/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0155 - accuracy: 0.9954
# Epoch 6/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0107 - accuracy: 0.9967
# Epoch 7/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0087 - accuracy: 0.9970
# Epoch 8/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0068 - accuracy: 0.9978
# Epoch 9/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0043 - accuracy: 0.9984
# Epoch 10/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0043 - accuracy: 0.9985
